# %% [markdown]
# # Morphology

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv2
import pandas as pd

# %% [markdown]
# ## Image Letras.png

# %%
# Open image
image = cv2.imread("letras.png")

# %%
gris = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
(th, bw) = cv2.threshold(gris, 140, 255, cv2.THRESH_BINARY_INV)  # el objeto a analizar lo queremos en los pixeles blancos.

# %%
def skeletonize(img):
    img = img.copy() # don't clobber original
    skel = img.copy()

    skel[:,:] = 0
    kernel = cv2.getStructuringElement(cv2.MORPH_CROSS, (3,3))

    while True:
        eroded = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)
        temp = cv2.morphologyEx(eroded, cv2.MORPH_DILATE, kernel)
        temp  = cv2.subtract(img, temp)
        skel = cv2.bitwise_or(skel, temp)
        img[:,:] = eroded[:,:]
        if cv2.countNonZero(img) == 0:
            break

    return skel

# %%
skeleton = skeletonize(gris)
plt.imshow(skeleton, cmap='gray')

# %% [markdown]
# ## Image color

# %%
# Open image
image = cv2.imread("caballo.png")

# %%
gris = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
(th, bw) = cv2.threshold(gris, 140, 255, cv2.THRESH_BINARY_INV)  # el objeto a analizar lo queremos en los pixeles blancos.

# %%
def skeletonize(img):
    img = img.copy() # don't clobber original
    skel = img.copy()

    skel[:,:] = 0
    kernel = cv2.getStructuringElement(cv2.MORPH_CROSS, (3,3))

    while True:
        eroded = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)
        temp = cv2.morphologyEx(eroded, cv2.MORPH_DILATE, kernel)
        temp  = cv2.subtract(img, temp)
        skel = cv2.bitwise_or(skel, temp)
        img[:,:] = eroded[:,:]
        if cv2.countNonZero(img) == 0:
            break

    return skel

# %%
skeleton = skeletonize(bw)
plt.imshow(skeleton, cmap='gray')
